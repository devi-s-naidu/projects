# %% [markdown]
# <a href="https://colab.research.google.com/github/Devi-s-naidu/Resolute_AI_software_internship/blob/main/Task_4_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#video capture opencv  ##working

import cv2
import numpy as np
import matplotlib.pyplot as plt

vid = cv2.VideoCapture(0)

while(True):
    ret,frame = vid.read()
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video.release()
cv2.destroyAllWindows()

# %%
# !pip install opencv-python

# %%
import cv2

# %%
#python intro and loading images  ##working

import cv2
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# 0
img= cv2.imread('C:\\Users\\91910\\Downloads\\watch.jpg',cv2.IMREAD_GRAYSCALE)
#IMREAD_COLOR=1
#IMREAD_UNCHANGED=-1
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
#plt.imshow(img, cmap='gray',interpolation ='bicubic')
#plt.xtickd([]),plt.yticks([])
#plt.plot([200,300,400],[100,200,300],'c',linewidth=5)
#plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:\\Users\\91910\\Downloads\\watch.jpg')
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(new_img)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap='gray',interpolation='bicubic')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

pic= cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg",0)
plt.imshow(pic,cmap="gray")

# %%
#thresholding
import cv2
import matplotlib.pyplot as plt

pic= cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg",0)
ret,th=cv2.threshold(pic,127,255,cv2.THRESH_BINARY)
plt.imshow(th,cmap="gray")
# plt.imshow(pic,cmap="gray")

# %%
#adaptive thresholding
import cv2
import matplotlib.pyplot as plt

pic= cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg",0)
th=cv2.adaptiveThreshold(pic,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,5,1)
plt.imshow(th,cmap="gray")

# %%
#morphological Transformation on images ##working
#erosion
import cv2
import numpy as np
import matplotlib.pyplot as plt

image=cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg",0)
kernel=np.ones((5,5),np.uint0)
ersoion=cv2.erode(image,kernel,iterations=1)
cv2.imshow("original",image)
cv2.imshow("erosion",ersoion)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#morphological transformations on images ##working
#dilation
import cv2
import numpy as np
import matplotlib.pyplot as plt

image=cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg",0)
kernel=np.ones((5,5),np.uint0)
dilation=cv2.dilate(image,kernel,iterations=1)
cv2.imshow("original",image)
cv2.imshow("dilation",dilation)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#template matching ##working

import cv2 as cv
import numpy as np
or_img=cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg",1)
or_gray_img=cv2.cvtColor(or_img,cv2.COLOR_BGR2GRAY)
template=cv2.imread("C:\\Users\\91910\\Downloads\\watch1.jpeg",0)
w,h=template.shape[::-1]
res=cv2.matchTemplate(or_gray_img,template,cv2.TM_CCOEFF_NORMED)
th=0.8
loc=np.where(res>=th)
for pt in zip(*loc[::-1]):
    cv2.rectangle(or_img,pt,(pt[0]+w,pt[1]+h),(0,255,200),1)

cv2.imshow("watch dial found",or_img)
key=cv2.waitKey(0)
if key==81:
    exit

# %%
#Grabcut Foreground Extraction  ##working
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread("C:\\Users\\91910\\Downloads\\watch.jpg")
mask=np.zeros(img.shape[:2],np.uint8)
bdgModel=np.zeros((1,65),np.float64)
fdgModel=np.zeros((1,65),np.float64)
rect=(50,50,800,500)
cv2.grabCut(img,mask,rect,bdgModel,fdgModel,5,cv2.GC_INIT_WITH_RECT)
mask2=np.where((mask==2)|(mask==0),0,1).astype('uint8')
img=img*mask2[:,:,np.newaxis]
plt.imshow(img)
plt.colorbar()
plt.show()

# %%
#corner detection  ##working
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img=cv.imread("C:\\Users\\91910\\Downloads\\watch.jpg")
gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
gray=np.float32(gray)

corners=cv.goodFeaturesToTrack(gray,50,0.01,10)
corners=np.int0(corners)
for corner in corners:
    x,y=corner.ravel()
    cv.circle(img,(x,y),3,255,-1)
cv.imshow('corner',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Brute force matching  ##working
import cv2
import numpy as np
import matplotlib.pyplot as plt

img1=cv2.imread("C:\\Users\\91910\\Downloads\\booktemplate.jpeg",1)
img2=cv2.imread("C:\\Users\\91910\\Downloads\\book.jpeg",1)
orb=cv2.ORB_create()
kp1,des1=orb.detectAndCompute(img1,None)
kp2,des2=orb.detectAndCompute(img2,None)
bf=cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck=True)
matches=bf.match(des1,des2)
matches=sorted(matches,key=lambda x:x.distance)
img3= cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=2) #we drew 10 matches
plt.imshow(img3)
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#loading video source in grayscale  ##working

import cv2
import numpy as np

cap=cv2.VideoCapture(0)

while True:
    ret, frame=cap.read()
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow("frame",gray)
    #1 cuz of loop
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
#loading images grayscale with matplotlib  ##working

import cv2
import numpy as no
import matplotlib.pyplot as plt

img=cv2.imread('C:\\Users\\91910\\Downloads\\watch.jpg',cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray', interpolation = 'bicubic')

#to hide the tick values on x and y axis
plt.xticks([]),plt.yticks([])

plt.plot([200,300,400],[100,200,300],'c',linewidth=2)
plt.show()

# %%
#Drawing and writing on image  ##working

import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('C:\\Users\\91910\\Downloads\\watch.jpg',cv2.IMREAD_COLOR)
cv2.line(img,(0,0),(200,300),(255,255,255),50)
cv2.rectangle(img,(500,250),(1000,500),(0,0,255),15)
cv2.circle(img,(447,63), 63, (255,0,255), -1)

pts = np.array([[100,50],[200,300],[700,200],[500,100]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img, [pts], True, (225,255,0), 3)

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'Devi',(10,500), font, 6, (200,0,155), 13, cv2.LINE_AA)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#image operations  ##working

import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:\\Users\\91910\\Downloads\\watch.jpg',cv2.IMREAD_COLOR)
#reference pixels
px = img[55,55]

#to change pixels
img[55,55] = [255,255,255]

#re-reference
px = img[55,55]
print(px)

#specifying region of Image(ROI)
px = img[100:150,100:150]
print(px)

#modifying ROI
img[100:150,100:150] = [255,255,255]
print(img.shape)
print(img.size)
print(img.dtype)
watch_face = img[37:111,107:194]
img[0:74,0:87] = watch_face
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [255 255 255]
# [[[210 213 218]
#   [210 213 218]
#   [210 213 218]
#   ...
#   [207 209 219]
#   [207 209 219]
#   [208 210 220]]
#
#  [[209 212 217]
#   [210 213 218]
#   [209 212 217]
#   ...
#   [208 210 220]
#   [208 210 220]
#   [209 211 221]]
#
#  [[206 208 216]
#   [206 208 216]
#   [206 208 216]
#   ...
#   [209 211 221]
#   [209 211 221]
#   [209 211 221]]
#
#  ...
#
#  [[172 177 198]
#   [176 181 202]
#   [178 183 204]
#   ...
#   [183 192 206]
#   [182 191 205]
#   [182 191 205]]
#
#  [[171 176 197]
#   [175 180 201]
#   [177 182 203]
#   ...
#   [183 192 206]
#   [182 191 205]
#   [181 190 204]]
#
#  [[171 176 197]
#   [175 180 201]
#   [177 182 203]
#   ...
#   [182 191 205]
#   [181 190 204]
#   [181 190 204]]]
# (980, 736, 3)
# 2163840
# uint8

# %%
#image arithmetics and logic  ##working

#simple addition of images
import cv2
img1 = cv2.imread("C:\\Users\\91910\\Downloads\\template1.jpeg")
img2 = cv2.imread("C:\\Users\\91910\\Downloads\\template1.jpeg")
add = img1 + img2
sub = img1 - img2
add1 = cv2.add(img1 ,img2)
cv2.imshow("addition",add)
cv2.imshow("subtraction",sub)
cv2.imshow("addition1",add1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#addition of logo onto an image  ##working

import cv2
import numpy as np
import matplotlib.pyplot as plt

img1 = cv2.imread('C:\\Users\\91910\\Downloads\\watch.jpg')
img2 = cv2.imread('C:\\Users\\91910\\Downloads\\mainlogo.jpeg')
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV)
mask_inv = cv2.bitwise_not(mask)
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst
cv2.imshow('res',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#color filtering ##working

import cv2
import numpy as np
cap = cv2.VideoCapture(0)
while(1):
    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    #dark_red = np.uint8([[[12,22,121]]])
    #dark_red = cv2.cvtColor(dark_red,cv2.COLOR_BGR2HSV)
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)
    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()
cap.release()

# %%
#blurring and smoothing  ##working

import cv2
import numpy as np
cap = cv2.VideoCapture(0)
while(1):
    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)
    kernel = np.ones((15,15),np.float32)/225
    smoothed = cv2.filter2D(res,-1,kernel)
    cv2.imshow('Original',frame)
    cv2.imshow('Averaging',smoothed)
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()
cap.release()

#gaussian blurring
#blur = cv2.GaussianBlur(res,(15,15),0)
#cv2.imshow('Gaussian Blurring',blur)

#median blurring
#median = cv2.medianBlur(res,15)
#cv2.imshow('Median Blur',median)

#bilateral blurring
#bilateral = cv2.bilateralFilter(res,15,75,75)
#cv2.imshow('bilateral Blur',bilateral)

# %%
#morphological Transformation on opencv  ##working
#erosion and dilation
import cv2
import numpy as np

cap = cv2.VideoCapture(0)
while(1):
    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)
    kernel = np.ones((5,5),np.uint8)
    erosion = cv2.erode(mask,kernel,iterations = 1)
    dilation = cv2.dilate(mask,kernel,iterations = 1)
    cv2.imshow('Original',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('Erosion',erosion)
    cv2.imshow('Dilation',dilation)
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()
cap.release()

#removing false positives-opening
#removing false negatives-closing
#opening = cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernel)
#dilation = cv2.morphologyEx(mask,cv2.MORPH_CLOSE,kernel)
#cv2.imshow('Original',frame)
#cv2.imshow('Mask',mask)
#cv2.imshow('opening,erosion)
#cv2.imshow('closing',dilation)

# %%
#canny Edge Detecion ##working

import cv2
import numpy as np
cap = cv2.VideoCapture(0)
while(1):
    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)
    cv2.imshow('Original',frame)
    edges = cv2.Canny(frame,100,200)
    cv2.imshow('Edges',edges)
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()
cap.release()

# %%
#MOG background reduction  ##working
import numpy as np
import cv2
cap = cv2.VideoCapture('C:\\Users\\91910\\Downloads\\people-walking.mp4')
fgbg = cv2.createBackgroundSubtractorMOG2()
while(1):
    ret, frame = cap.read()
    fgmask = fgbg.apply(frame)
    cv2.imshow('fgmask',frame)
    cv2.imshow('frame',fgmask)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
#Haar Cascade Object Detection
#face and eye detection
import numpy as np
import cv2
# multiple cascades: https://github.com/Itseez/opencv/tree/master/data/haarcascades
#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
face_cascade = cv2.CascadeClassifier('C:\\Users\\91910\\anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml')
#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
eye_cascade = cv2.CascadeClassifier('C:\\Users\\91910\\anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_eye.xml')
cap = cv2.VideoCapture(0)
while 1:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
    cv2.imshow('img',img)
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
#creating own Haar Cascade

import cv2
cap=cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier('C:\\Users\\91910\\Downloads\\custom haar cascade\\strawberry.xml')
while(True):
    ret,frame=cap.read()
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(gray,1.3,5)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF==('q'):
        break
cap.release()
cv2.destroyAllWindows()
